# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-изучение-общей-информации" data-toc-modified-id="Загрузка-данных-и-изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Знакомство-с-данными" data-toc-modified-id="Знакомство-с-данными-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Знакомство с данными</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Площадь,-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Площадь, цена, число комнат, высота потолков</a></span></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li><li><span><a href="#Редкие-и-выбивающиеся-значения" data-toc-modified-id="Редкие-и-выбивающиеся-значения-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Редкие и выбивающиеся значения</a></span></li><li><span><a href="#Что-больше-всего-влияет-на-стоимость-квартиры" data-toc-modified-id="Что-больше-всего-влияет-на-стоимость-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Что больше всего влияет на стоимость квартиры</a></span></li><li><span><a href="#10-населённых-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="10-населённых-пунктов-с-наибольшим-числом-объявлений-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>10 населённых пунктов с наибольшим числом объявлений</a></span></li><li><span><a href="#Центральный-сегмент" data-toc-modified-id="Центральный-сегмент-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Центральный сегмент</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Продажа квартир в Санкт-Петербурге — анализ рынка недвижимости

# %% [markdown]
# **Описание проекта**
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость: архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Задача проекта**
#
# Используя данные сервиса Яндекс.Недвижимость, определить рыночную стоимость объектов недвижимости и типичные параметры квартир.

# %% [markdown]
# **Описание данных**
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# **План работы**
#
# 1. Загрузка данных и изучение общей информации
# 2. Предобработка данных
# 3. Расчеты и добавление результатов в таблицу
# 4. Исследовательский анализ данных
# 5. Подведение итогов исследования

# %% [markdown]
# ## Загрузка данных и изучение общей информации

# %% [markdown]
# ### Знакомство с данными

# %% [markdown]
# Импортируем файл с данными и изучим общую информацию:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/OT/Desktop/проекты/Недвижимость/real_estate_data.csv', sep='\t')
df.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# В таблице 23 699 строк и 22 столбца. Встречаются 4 типа данных: bool, float64, int64 и object. Количество значений в столбцах различается. Значит, в данных есть пропущенные значения. В семи столбцах нужно изменить тип данных:с float64 на int64 в столбцах floors_total, balcony, parks_around3000, ponds_around3000, days_exposition, c object на bool в столбце is_apartment, с object на datetime64 в столбце first_day_exposition.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Данные в таблице представляют собой информацию об объявлениях о продаже объектов недвижимости (срок публикации, цена объекта и т.д.). В таблице 4 типа данных. Перед проведением исследования необходимо обработать пропущенные значения и изменить тип данных в указанных выше столбцах.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Определим количество пропущенных значений:

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Пропущены значения в 14 столбцах, количество пропущенных значений в них отличается. Полное совпадение - 5518 значений - в столбцах parks_around3000 и ponds_around3000.

# %% [markdown]
# Для наглядности выведем строки с пропущенными значениями:

# %%
df[df['parks_around3000'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Balcony - вероятно, число балконов не указано просто потому, что в этих объектах балконов нет. Заменим здесь пропуски на 0:

# %%
print('Пропуски до:', df['balcony'].isna().sum())
df['balcony'] = df['balcony'].fillna(0)
print('Пропуски после:', df['balcony'].isna().sum())
# Out:
# Пропуски до: 11519
# Пропуски после: 0

# %% [markdown]
# Locality_name и floors_total - здесь количество пропусков совсем незначительное, пропуски удалим:

# %%
print('Пропуски до:', df['locality_name'].isna().sum())
df.dropna(subset=['locality_name'],inplace=True)
print('Пропуски после:', df['locality_name'].isna().sum())
# Out:
# Пропуски до: 49
# Пропуски после: 0

# %%
print('Пропуски до:', df['floors_total'].isna().sum())
df.dropna(subset=['floors_total'],inplace=True)
print('Пропуски после:', df['floors_total'].isna().sum())
# Out:
# Пропуски до: 85
# Пропуски после: 0

# %% [markdown]
# Пропущенные значения в столбце is_apartment скорее всего означают, что данные объекты недвижимости не являются апартаментами. Заменим здесь тип данных на bool,тогда NaN превратится в False:

# %%
df['is_apartment'] = df['is_apartment'].astype('bool')
df['is_apartment'].value_counts()
# Out:
# True     20855
# False     2710
# Name: is_apartment, dtype: int64

# %% [markdown]
# Пропуски в столбце kitchen_area могли возникнуть предположительно из-за того, что это студии и квартиры со свободной планировкой, где нет кухни как отдельного помещения. Посмотрим, сколько таких объектов в объявлениях:

# %%
df['studio'].value_counts()
# Out:
# False    23419
# True       146
# Name: studio, dtype: int64

# %% [markdown]
# Количество студий - 146.

# %%
df['open_plan'].value_counts()
# Out:
# False    23498
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# Количество объектов свободной планировки - 67.

# %%
no_kitchen = (df['studio'] == True) + (df['open_plan'] == True)
print('Число квартир без кухни:',no_kitchen.sum())
# Out:
# Число квартир без кухни: 213

# %% [markdown]
# Квартир без кухни как отдельного помещения намного меньше, чем пропущенных значений. Значит, не все пропуски связаны с типом недвижимости. Проверим, во всех ли студиях и квартирах свободной планировки есть пропуски в kitchen_area:

# %%
len(df[(df['kitchen_area'].isna()) & (df['studio'] == True)])
# Out:
# 146

# %%
len(df[(df['kitchen_area'].isna()) & (df['open_plan'] == True)])
# Out:
# 67

# %% [markdown]
# Для студий и свободной планировки заменим пропуски в kitchen_area на 0:

# %%
print('Пропуски до:', df['kitchen_area'].isna().sum())
df.loc[(df['studio'] == True)& (df['kitchen_area'].isna()), 'kitchen_area'] = 0
print('Пропуски после:', df['kitchen_area'].isna().sum())
# Out:
# Пропуски до: 2222
# Пропуски после: 2076

# %%
print('Пропуски до:', df['kitchen_area'].isna().sum())
df.loc[(df['open_plan'] == True)& (df['kitchen_area'].isna()), 'kitchen_area'] = 0
print('Пропуски после:', df['kitchen_area'].isna().sum())
# Out:
# Пропуски до: 2076
# Пропуски после: 2009

# %% [markdown]
# Остальные пропуски заменим медианой с разбивкой по всему набору данных:

# %%
print('Пропуски до:', df['kitchen_area'].isna().sum())
df.loc[df['kitchen_area'].isna(), 'kitchen_area'] = df['kitchen_area'].median()
print('Пропуски после:', df['kitchen_area'].isna().sum())
# Out:
# Пропуски до: 2009
# Пропуски после: 0

# %% [markdown]
# Заполним пропуски в living_area с разбивкой по количеству комнат:

# %%
print('Пропуски до:', df['living_area'].isna().sum())
df['living_area'] = df['living_area'].fillna(
                            df.groupby('rooms')['living_area'].transform(func='median'))
print('Пропуски после:', df['living_area'].isna().sum())
# Out:
# Пропуски до: 1865
# Пропуски после: 0

# %% [markdown]
# Пропуски в ceiling_height, airports_nearest, cityCenters_nearest, parks_nearest и ponds_nearest заменим медианой по всему набору данных:

# %%
print('Пропуски до:', df['ceiling_height'].isna().sum())
df.loc[df['ceiling_height'].isna(), 'ceiling_height'] = df['ceiling_height'].median()
print('Пропуски после:', df['ceiling_height'].isna().sum())
# Out:
# Пропуски до: 9084
# Пропуски после: 0

# %%
print('Пропуски до:', df['airports_nearest'].isna().sum())
df.loc[df['airports_nearest'].isna(), 'airports_nearest'] = df['airports_nearest'].median()
print('Пропуски после:', df['airports_nearest'].isna().sum())
# Out:
# Пропуски до: 5524
# Пропуски после: 0

# %%
print('Пропуски до:', df['cityCenters_nearest'].isna().sum())
df.loc[df['cityCenters_nearest'].isna(), 'cityCenters_nearest'] = df['cityCenters_nearest'].median()
print('Пропуски после:', df['cityCenters_nearest'].isna().sum())
# Out:
# Пропуски до: 5501
# Пропуски после: 0

# %%
print('Пропуски до:', df['parks_nearest'].isna().sum())
df.loc[df['parks_nearest'].isna(), 'parks_nearest'] = df['parks_nearest'].median()
print('Пропуски после:', df['parks_nearest'].isna().sum())
# Out:
# Пропуски до: 15535
# Пропуски после: 0

# %%
print('Пропуски до:', df['ponds_nearest'].isna().sum())
df.loc[df['ponds_nearest'].isna(), 'ponds_nearest'] = df['ponds_nearest'].median()
print('Пропуски после:', df['ponds_nearest'].isna().sum())
# Out:
# Пропуски до: 14529
# Пропуски после: 0

# %% [markdown]
# Число пропусков в столбцах parks_around3000 и ponds_around3000 совпадает:

# %%
print('Число пропусков в parks_around3000:', df['parks_around3000'].isna().sum())
print('Число пропусков в ponds_around3000:', df['ponds_around3000'].isna().sum())
# Out:
# Число пропусков в parks_around3000: 5500
# Число пропусков в ponds_around3000: 5500

# %% [markdown]
# Вероятно, это пропуски в одних и тех же строках таблицы. Проверим это предположение:

# %%
len(df[(df['parks_around3000'].isna()) & (df['ponds_around3000'].isna())])
# Out:
# 5500

# %% [markdown]
# Заполним пропуски медианой:

# %%
print('Пропуски до:', df['parks_around3000'].isna().sum())
df.loc[df['parks_around3000'].isna(), 'parks_around3000'] = df['parks_around3000'].median()
print('Пропуски после:', df['parks_around3000'].isna().sum())
# Out:
# Пропуски до: 5500
# Пропуски после: 0

# %%
print('Пропуски до:', df['ponds_around3000'].isna().sum())
df.loc[df['ponds_around3000'].isna(), 'ponds_around3000'] = df['ponds_around3000'].median()
print('Пропуски после:', df['ponds_around3000'].isna().sum())
# Out:
# Пропуски до: 5500
# Пропуски после: 0

# %% [markdown]
# Прежде чем заполнять пропуски в столбцe days_exposition, посмотроим график зависимости числа пропусков от даты публикации объявления. Сначала изменим тип данных в столбце first_day_exposition:

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y.%m.%dT%H:%M:%S')
df['days_exposition_nan'] = df['days_exposition'].isna().astype(int)
df.groupby('first_day_exposition').agg({'days_exposition_nan': 'sum'}).plot(figsize=(8,6))
plt.xlabel('Дата размещения'), plt.ylabel('Количество объявлений')
plt.title('Распределение объявлений с пропусками')
plt.show;

# %% [markdown]
# На графике видно, что количество пропусков в days_exposition растет к 2019 году. Это незакрытые объявления, поэтому пропуски оставим, т.к. срок размещения объявления неизвестен.

# %%
#удаляем созданный выше столбец
del df['days_exposition_nan']

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# В двух столбцах мы уже изменили тип данных выше (в is_apartment и first_day_exposition). Теперь изменим остальные:

# %%
#применим цикл:
columns = ['balcony', 'floors_total', 'parks_around3000','ponds_around3000']
for i in columns:
    df[i] = df[i].astype('int64')

# %% [markdown]
# Проверим общую информацию по обновленной таблице:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest           0
# cityCenters_nearest        0
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3171
# dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Пропуски заполнены (кроме столбца days_exposition по указаной выше причине), тип данных изменен, где это требовалось.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Посчитаем и добавим в таблицу следующие данные:
# price_sqm - цена кв. метра;
# weekday, month, year - день недели, месяц, год публикации объявления;
# floor_group - этаж (первый, последний, другой);
# ratio_living_total - соотношение жилой и общей площади;
# ratio_kitchen_total - отношение площади кухни к общей.

# %%
df['price_sqm'] = df['last_price'] / df['total_area']

# %%
df['weekday'] = pd.DatetimeIndex(df['first_day_exposition']).weekday
df['month'] = pd.DatetimeIndex(df['first_day_exposition']).month
df['year'] = pd.DatetimeIndex(df['first_day_exposition']).year

# %%
#функция для группировки по этажам:
def floor_group(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
df['floor_group'] = df.apply(floor_group, axis = 1)

# %%
df['ratio_living_total'] = df['living_area'] / df['total_area']
df['ratio_kitchen_total'] = df['kitchen_area'] / df['total_area']

# %%
#проверим новые столбцы:
new_columns = df[['price_sqm','weekday', 'month', 'year', 'floor_group','ratio_living_total', 'ratio_kitchen_total']]
new_columns.head()
# Out:
#        price_sqm  weekday  month  year floor_group  ratio_living_total  \
# 0  120370.370370        3      3  2019      другой            0.472222
# 1   82920.792079        1     12  2018      первый            0.460396
# 2   92785.714286        3      8  2015      другой            0.612500
# 3  408176.100629        4      7  2015      другой            0.283019
# 4  100000.000000        1      6  2018      другой            0.320000
#
#    ratio_kitchen_total
# 0             0.231481
# 1             0.272277
# 2             0.148214
# 3             0.056604
# 4             0.410000

# %% [markdown]
# Мы достаточно детально обработали данные и добавили все необходимые значения в выборку. Теперь проведём анализ.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Площадь, цена, число комнат, высота потолков

# %% [markdown]
# Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Очистим данные от аномалий.

# %%
df['total_area'].hist(bins=30, range=(10, 200), figsize=(8,5))
plt.title('Площадь квартир')
plt.xlabel('Площадь в кв.м')
plt.ylabel('Частота')
plt.show();

# %%
df.boxplot('total_area')
plt.ylim(0, 920);

# %%
df['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Среднее и медианное значение площади - 60.32 и 52. Наиболее часто встречаются квартиры площадью 40 - 48 кв.м.

# %%
df['last_price'].describe().round()
# Out:
# count        23565.0
# mean       6540058.0
# std       10910935.0
# min          12190.0
# 25%        3400000.0
# 50%        4646000.0
# 75%        6790000.0
# max      763000000.0
# Name: last_price, dtype: float64

# %%
df['last_price'].hist(bins=30, range=(0, 20000000), figsize=(8,5))
plt.title('Стоимость квартир')
plt.xlabel('Цена')
plt.ylabel('Частота')
plt.ticklabel_format(style='plain')
plt.show();

# %%
df.boxplot('last_price')
plt.ylim(-10000000, 800000000)
plt.show();

# %% [markdown]
# Среднее и медианное значение стоимости - 6540058 и 4646000. В основном стоимость квартир составляет 5 млн.

# %%
df.plot(y='rooms', kind='hist', title='Комнаты', figsize=(10,7))
plt.xlabel('Число комнат')
plt.ylabel('Частота')
plt.show();

# %%
df.boxplot('rooms')
plt.ylim(0, 20)
plt.show();

# %%
df['rooms'].describe()
# Out:
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Среднее и медианное значение комнат совпадают: 2. У большинства квартир от 2 до 4 комнат.

# %%
plt.hist(df.query('(ceiling_height > 2) & (ceiling_height < 4)')['ceiling_height'], bins=20)
plt.title('Потолки')
plt.xlabel('Высота потолка')
plt.ylabel('Частота')
plt.show();

# %%
df['ceiling_height'].plot.box(grid=True)
plt.ylim(1, 6)
plt.show();

# %%
df['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Среднее и медианное значение высоты потолка почти совпадают: 2.72 и 2.65. У большинства квартир высота потолка 2.6 - 2.7м.

# %% [markdown]
# ### Время продажи квартиры

# %% [markdown]
# Изучим время продажи квартиры:

# %%
df['days_exposition'].hist(bins=50, figsize=(8,6))
plt.title('Время продажи квартир')
plt.show();

# %%
df.boxplot(column = 'days_exposition') 
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
max_years = df['days_exposition'].max()/365
print('Максимальный срок в годах:','{:.1f}'.format(max_years))
# Out:
# Максимальный срок в годах: 4.3

# %% [markdown]
# В среднем квартира продается за 181 день. Медиана - 95 дней. Минимальный срок - 1 день, максимальный - 4 года. Быстрой продажей можно назвать срок меньше 45 дней. Долгой продажей - от 231 дня (7 месяцев).

# %% [markdown]
# ### Редкие и выбивающиеся значения

# %% [markdown]
# Удалим выбросы в 5 столбцах:

# %%
# расчет IQR для total_area
q1 = df['total_area'].quantile(0.25)
q3 = df['total_area'].quantile(0.75)
iqr = q3 - q1 
q1 - 1.5 * iqr, q3 + 1.5 * iqr
# Out:
# (-4.550000000000004, 114.25)

# %%
# расчет IQR для last_price
q1 = df['last_price'].quantile(0.25)
q3 = df['last_price'].quantile(0.75)
iqr = q3 - q1 
q1 - 1.5 * iqr, q3 + 1.5 * iqr
# Out:
# (-1685000.0, 11875000.0)

# %%
# расчет IQR для rooms
q1 = df['rooms'].quantile(0.25)
q3 = df['rooms'].quantile(0.75)
iqr = q3 - q1 
q1 - 1.5 * iqr, q3 + 1.5 * iqr
# Out:
# (-2.0, 6.0)

# %%
# расчет IQR для ceiling_height
q1 = df['ceiling_height'].quantile(0.25)
q3 = df['ceiling_height'].quantile(0.75)
iqr = q3 - q1 
q1 - 1.5 * iqr, q3 + 1.5 * iqr
# Out:
# (2.45, 2.8500000000000005)

# %%
# расчет IQR для days_exposition
q1 = df['days_exposition'].quantile(0.25)
q3 = df['days_exposition'].quantile(0.75)
iqr = q3 - q1 
q1 - 1.5 * iqr, q3 + 1.5 * iqr
# Out:
# (-234.0, 510.0)

# %%
#удаляем выбросы
new_df = df[(df['total_area'] >= 12) & (df['total_area'] <= 114.25) &
            (df['last_price'] >= 1000000) & (df['last_price'] <= 11875000) &
            (df['rooms'] >= 1) & (df['rooms'] <= 6) &
            (df['ceiling_height'] >= 2.45) & (df['ceiling_height'] <= 2.85) &
            ((df['days_exposition'].isna()) | (df['days_exposition'] <= 510))]
print('Выборка для анализа составляет: {:.2%}'.format(len(new_df)/len(df)))
# Out:
# Выборка для анализа составляет: 75.70%

# %% [markdown]
# После удаления выбросов для дальнейшего анализа осталось 75.70% от исходной таблицы.

# %% [markdown]
# ### Что больше всего влияет на стоимость квартиры

# %% [markdown]
# Посмотрим, какие факторы наиболее влияют на стоимость квартиры. Изучим зависимость цены от различных параметров. Для этого построим диаграммы и рассчитаем корреляцию.

# %%
#пример использования цикла для графиков
columns = ['last_price','total_area','rooms', 'ceiling_height']
for column in columns:
    new_df.plot(x = column, y = 'price_sqm', kind ='scatter', alpha = 0.5)

# %%
new_df.plot(x='last_price', y='total_area', kind='scatter', alpha=0.3, label='Зависимость цены от площади');

# %%
print('Коэффициент корелляции цены и площади:')
print(new_df['last_price'].corr(new_df['total_area']))
# Out:
# Коэффициент корелляции цены и площади:
# 0.6793704506299841

# %%
new_df.plot(x='last_price', y='rooms', kind='scatter', alpha=0.3, label='Зависимость цены от числа комнат');

# %%
print('Коэффициент корелляции цены и числа комнат:')
print(new_df['last_price'].corr(new_df['rooms']))
# Out:
# Коэффициент корелляции цены и числа комнат:
# 0.40999770497703375

# %%
new_df.plot(x='last_price', y='cityCenters_nearest', kind='scatter', alpha=0.3, figsize=(15,5), 
            label='Зависимость от удаленности от центра');

# %%
print('Коэффициент корелляции цены и расстояния до центра:')
print(new_df['last_price'].corr(new_df['cityCenters_nearest']))
# Out:
# Коэффициент корелляции цены и расстояния до центра:
# -0.170518400383981

# %%
new_df.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar')
plt.title('Зависимость от категории этажа')
plt.ylim(1000000, 7000000);

# %%
# Зависимость от дня размещения
(
    new_df.pivot_table(index='weekday', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость от дня')
plt.show()
# Зависимость от месяца размещения
(
    new_df.pivot_table(index='month', values='last_price')
    .plot(grid=True, style='o-', xlim=(1,12), figsize=(10, 5))
)
plt.title('Зависимость от месяца')
plt.show()
# Зависимость от года размещения
(
    new_df.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость от года')
plt.show()

# %%
#cоберем столбцы для матрицы рассеяния:
matrix_df = new_df[['last_price', 'total_area', 'rooms','cityCenters_nearest', 'floor_group','weekday', 'month', 'year' ]]
pd.plotting.scatter_matrix(matrix_df, figsize=(9, 9))
# Out:
# array([[<AxesSubplot:xlabel='last_price', ylabel='last_price'>,
#         <AxesSubplot:xlabel='total_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='rooms', ylabel='last_price'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='last_price'>,
#         <AxesSubplot:xlabel='weekday', ylabel='last_price'>,
#         <AxesSubplot:xlabel='month', ylabel='last_price'>,
#         <AxesSubplot:xlabel='year', ylabel='last_price'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='total_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='total_area'>,
#         <AxesSubplot:xlabel='weekday', ylabel='total_area'>,
#         <AxesSubplot:xlabel='month', ylabel='total_area'>,
#         <AxesSubplot:xlabel='year', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='rooms'>,
# ...

# %%
#cоберем общую таблицу по корреляции:
cm = matrix_df.corr()
cm
# Out:
#                      last_price  total_area     rooms  cityCenters_nearest  \
# last_price             1.000000    0.679370  0.409998            -0.170518
# total_area             0.679370    1.000000  0.798095            -0.048838
# rooms                  0.409998    0.798095  1.000000            -0.022387
# cityCenters_nearest   -0.170518   -0.048838 -0.022387             1.000000
# weekday               -0.006255   -0.003748  0.001050             0.000967
# month                  0.008266    0.015372  0.001924            -0.011254
# year                   0.035120   -0.038261 -0.017864             0.001078
#
#                       weekday     month      year
# last_price          -0.006255  0.008266  0.035120
# total_area          -0.003748  0.015372 -0.038261
# rooms                0.001050  0.001924 -0.017864
# cityCenters_nearest  0.000967 -0.011254  0.001078
# weekday              1.000000  0.012346 -0.008109
# month                0.012346  1.000000 -0.298645
# ...

# %%
plt.figure(figsize=(14,8))
sns.heatmap(cm, annot = True, square=False)
plt.title('Матрица корреляций признаков', fontsize = 20)
plt.xlabel('Признаки', fontsize = 14) 
plt.ylabel('Признаки', fontsize = 14) 
plt.show();

# %% [markdown]
# Наиболее четко выражена зависимость цены от площади квартиры и количества комнат. В большинстве случаев цена напрямую зависит от площади, однако есть отдельные дорогие, но небольшие по площади объекты. Возможно, их стоимость связана, например, с расположением в центре города. Число комнат также влияет на цену, однако зависимость несколько слабее, чем у площади. Вероятно, во многих объектах всего одна-две комнаты, но они большие, либо это большие квартиры свободной планировки. Корелляция с остальными параметрами слабая, нет выраженной линейной связи. Возможно, она имеет более сложный характер. В центре города есть как дорогое, так и дешевое жилье. Этаж не влияет на цену напрямую, однакоо квартиры не на первом и не на последнем этаже чуть дороже.

# %% [markdown]
# Зависимость от дня, месяца и года:
# - День недели: дороже всего квартиры, опубликованные во вторник и среду, дешевле всего - в субботу.
# - Месяц: дороже всего квартиры, продающиеся с апреля и ноября, дешевле всего - с июня.
# - Год: после 2014 года наблюдается резкий спад цен на недвижимость. Квартиры очень сильно подешевели в 2015 году. В 2018 году цены снова стали повышаться. Это соотносится с общей экономической ситуацией в стране в этот период.

# %% [markdown]
# ### 10 населённых пунктов с наибольшим числом объявлений

# %% [markdown]
# Сравнение средней стоимости квадратного метра в топ-10 населенных пунктов:

# %%
#определим 10 населенных пунктов с максимумом объявлений:
top_10 = new_df['locality_name'].value_counts().head(10).index
top_10
# Out:
# Index(['Санкт-Петербург', 'посёлок Мурино', 'посёлок Шушары', 'Всеволожск',
#        'посёлок Парголово', 'Колпино', 'Пушкин', 'Гатчина', 'деревня Кудрово',
#        'Выборг'],
#       dtype='object')

# %%
# сравним среднюю цену кв. метра в топ-10, сразу отсортируем по убыванию:
new_df[new_df['locality_name'].isin(top_10)].groupby('locality_name').agg({'price_sqm':'mean'}).sort_values('price_sqm', ascending=False)
# Out:
#                        price_sqm
# locality_name
# Санкт-Петербург    104639.845142
# Пушкин              99405.990977
# деревня Кудрово     92461.369228
# посёлок Парголово   90171.366860
# посёлок Мурино      85299.026592
# посёлок Шушары      78193.198433
# Колпино             75318.835816
# Гатчина             68612.388414
# Всеволожск          66994.780559
# Выборг              58307.879163

# %% [markdown]
# Наибольшая средняя стоимость кв. метра, конечно, в Петербурге и Пушкине, который входит в состав Петербурга. Наименьшая стоимость в небольшом по численности населения Выборге, расположенном на большом расстоянии (139 км) от Санкт-Петербурга.

# %% [markdown]
# ### Центральный сегмент

# %% [markdown]
# Определение границы центральной зоны

# %%
new_df['center_km'] = new_df['cityCenters_nearest'] // 1000
report = (new_df.query('locality_name == "Санкт-Петербург"').groupby('center_km')
         .agg({'price_sqm' : 'mean'})
          .rename(columns = {'price_sqm' : 'Средняя цена м2'})
         )
report['Средняя цена м2'].plot(grid = True, figsize = (15, 3))
plt.xticks(report.index.values, report.index.values)
plt.show;

# %% [markdown]
# Центральная зона находится в пределах 7 км. Дальше 7 км средняя цена на квартиры резко снижается.

# %% [markdown]
# Анализ сегмента в центре:

# %%
#выделим сегмент в центре
spb_center = new_df.query('(locality_name == "Санкт-Петербург") & (center_km <= 7)')
spb_center.describe()
# Out:
#        total_images    last_price   total_area        rooms  ceiling_height  \
# count   1259.000000  1.259000e+03  1259.000000  1259.000000     1259.000000
# mean       9.532963  7.025574e+06    60.365123     2.115171        2.657808
# std        5.648232  2.187026e+06    20.204676     0.901465        0.075645
# min        0.000000  1.686000e+06    12.000000     1.000000        2.460000
# 25%        6.000000  5.300000e+06    44.000000     1.000000        2.650000
# 50%        9.000000  6.830000e+06    58.300000     2.000000        2.650000
# 75%       13.000000  8.600000e+06    73.400000     3.000000        2.650000
# max       32.000000  1.186686e+07   114.200000     6.000000        2.850000
#
#        floors_total  living_area        floor  kitchen_area      balcony  ...  \
# count   1259.000000  1259.000000  1259.000000   1259.000000  1259.000000  ...
# mean       8.147736    34.409468     4.525814     10.545274     0.362192  ...
# ...

# %% [markdown]
# Площадь - средняя 60 кв.м, медиана 58 кв.м. Цена - средняя 7 млн, медиана 6,8 млн. Число комнат - среднее и медиана 2.Высота потолков - среднее и медиана 2,6 м.

# %%
#зависимость цены от числа комнат
spb_center.groupby('rooms')['last_price'].agg('mean').plot()
plt.title('Зависимость от числа комнат');

# %%
#зависимость цены от этажа
spb_center.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar')
plt.title('Зависимость от категории этажа');

# %%
#зависимость от удаленности от центра
spb_center.plot(x='last_price', y='cityCenters_nearest', kind='scatter', alpha=0.3, figsize=(15,5), label='Зависимость от удаленности от центра');

# %%
# Зависимость от дня размещения
(
    spb_center.pivot_table(index='weekday', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость от дня')
plt.show()
# Зависимость от месяца размещения
(
    spb_center.pivot_table(index='month', values='last_price')
    .plot(grid=True, style='o-', xlim=(1,12), figsize=(10, 5))
)
plt.title('Зависимость от месяца')
plt.show()
# Зависимость от года размещения
(
    spb_center.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
plt.title('Зависимость от года')
plt.show();

# %% [markdown]
# В центральном сегменте наблюдается цена зависит от числа комнат. На первом этаже наиболее дешевые квартиры, последний и другие стоят примерно одинаково. Нет линейной связи с удаленностью от центра. Самые дорогие объявления опубликованы в воскресенье, в сентябре. Самые дешевые - в четверг и в июне. С 2015 года наблюдается стабильный рост цен на недвижимость, с 2018 начинается плавный спад.

# %% [markdown]
# Сравнение с данными по всему городу:

# %%
#выборка по всему городу
spb = new_df.query('locality_name == "Санкт-Петербург"')
spb_chosen = spb[['last_price', 'total_area', 'rooms','ceiling_height','cityCenters_nearest', 'floor_group','weekday', 'month', 'year' ]]
spb_chosen.describe()
# Out:
#          last_price    total_area         rooms  ceiling_height  \
# count  1.116400e+04  11164.000000  11164.000000    11164.000000
# mean   5.399787e+06     52.299768      1.912218        2.629643
# std    1.930337e+06     17.086435      0.868284        0.083561
# min    1.190000e+06     12.000000      1.000000        2.450000
# 25%    3.990000e+06     39.200000      1.000000        2.560000
# 50%    4.900000e+06     48.200000      2.000000        2.650000
# 75%    6.450000e+06     62.400000      3.000000        2.650000
# max    1.186686e+07    114.200000      6.000000        2.850000
#
#        cityCenters_nearest       weekday         month          year
# count         11164.000000  11164.000000  11164.000000  11164.000000
# mean          12942.919339      2.582676      6.433447   2017.492386
# std            4088.211797      1.789282      3.458739      0.931226
# min             399.000000      0.000000      1.000000   2014.000000
# ...

# %%
#выборка по центру
spb_center_cut = spb_center[['last_price', 'total_area', 'rooms','ceiling_height','cityCenters_nearest', 'floor_group','weekday', 'month', 'year']]
spb_center_cut.describe()
# Out:
#          last_price   total_area        rooms  ceiling_height  \
# count  1.259000e+03  1259.000000  1259.000000     1259.000000
# mean   7.025574e+06    60.365123     2.115171        2.657808
# std    2.187026e+06    20.204676     0.901465        0.075645
# min    1.686000e+06    12.000000     1.000000        2.460000
# 25%    5.300000e+06    44.000000     1.000000        2.650000
# 50%    6.830000e+06    58.300000     2.000000        2.650000
# 75%    8.600000e+06    73.400000     3.000000        2.650000
# max    1.186686e+07   114.200000     6.000000        2.850000
#
#        cityCenters_nearest      weekday        month         year
# count          1259.000000  1259.000000  1259.000000  1259.000000
# mean           5134.065131     2.628276     6.640191  2017.305004
# std            1739.004853     1.748502     3.401347     0.928646
# min             399.000000     0.000000     1.000000  2015.000000
# 25%            4080.000000     1.000000     4.000000  2017.000000
# ...

# %% [markdown]
# Площадь в центральном сегменте в среднем больше, чем по городу (60 и 52). Средняя цена больше на 2 млн (7 млн и 5 млн). Число комнат совпадает - чаще всего их 2. Высота потолков также совпадает.

# %%
#зависимость цены от числа комнат - сравнение
spb_center.groupby('rooms')['last_price'].agg('mean').plot()
spb.groupby('rooms')['last_price'].agg('mean').plot()
plt.title('Зависимость от числа комнат - сравнение');

# %% [markdown]
# Прямая зависимость цены от числа комнат - совпадает.

# %%
#зависимость цены от этажа
spb_center.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar', figsize =(8,5))
plt.title('Зависимость от этажа');

# %%
spb.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar', figsize =(8,5))
plt.title('Зависимость от этажа');

# %% [markdown]
# В центре цены на квартиры на первом этаже более низкие в сравнении с остальными квартирами, чем по городу в целом.

# %%
#зависимость от удаленности от центра
spb_center.plot(x='last_price', y='cityCenters_nearest', kind='scatter', alpha=0.3, figsize=(15,5), label='Зависимость от удаленности от центра')
spb.plot(x='last_price', y='cityCenters_nearest', kind='scatter', alpha=0.3, figsize=(15,5), label='Зависимость от удаленности от центра');

# %% [markdown]
# Нет связи между удаленностью от центра и стоимостью.

# %%
# Зависимость от года размещения
(
    spb_center.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
plt.title('Зависимость от года')
(
    spb.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
plt.show();

# %% [markdown]
# На обоих графиках рост цен с 2015 года, однако в центре наблюдается спад в 2018 году, в отличие от графика по всему городу.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Большинство квартир продается за 181 день.

# %% [markdown]
# В основном сегменте рынка стоимость квартиры зависит от площади и количества комнат. При этом площадь влияет в большей степени, чем количество комнат. Квартиры на первом и последнем этаже дешевле остальных.

# %% [markdown]
# После 2014 года наблюдался резкий спад цен на недвижимость. С 2018 года цены стали повышаться.

# %% [markdown]
# Самая высокая стоимость жилья в топ-10 населенных пунктов в Петербурге (104 тыс. за кв.м). Самая низкая — в Выборге (58 тыс. за кв.м)

# %% [markdown]
# Экономическая ситуация в стране сильно влияет на стоимость недвижимости.
